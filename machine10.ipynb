# %% [markdown]
# <center style="font-size: 30px;"> 3_1_3_var_cualitativas </center>
# <br>
# <center> Julio 13, 2026 </center>
#
# ![logoitqv1.jpg](attachment:8288c7cf-a18e-46f1-bdb9-232ef7c3c00e.jpg)
#
#
# # 0.1 01PAO26-26 - Variables cualitativas
#
# ![python_logo.png](attachment:28dd48e1-6c08-4cb2-9f2b-1fbd0aa11652.png)
#
# *Oswal Aaron Lopez Carrillo*
#
# [repositorio de git](https://github.com/Aaronlc24/machine)

# %%
 # Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Doctorado' 'Doctorado' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Doctorado' 'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Grado' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Master' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Doctorado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Doctorado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Master' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Secundaria' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Master'
#  'Master' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado' 'Master' 'Master'
#  'Master' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Master'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Grado'
#  'Master' 'Secundaria' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Secundaria' 'Master' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Grado']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear el DataFrame con la información existente
df = pd.DataFrame({"Nivel de estudios": nivel_estudios})

# Contar las frecuencias
frecuencia = df["Nivel de estudios"].value_counts()

# Diagrama de barras
frecuencia.plot(kind="bar")
plt.xlabel("Nivel de estudios")
plt.ylabel("Frecuencia absoluta")
plt.title("Diagrama de barras")
plt.show()

# Diagrama de sectores
frecuencia.plot(
    kind="pie",
    autopct="%1.2f%%",
    ylabel=""
)
plt.title("Diagrama de sectores")
plt.show()
